# %% [markdown]
# <a href="https://colab.research.google.com/github/WereszczynskiClasses/Phys240_Solutions/blob/main/Quatnum_Potential_Step_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  A well-known quantum mechanics problem involves a particle of
# mass $m$ that encounters a one-dimensional potential step, like this:
#
# ![qstep.jpg](data:image/jpeg;base64,...)
#
# The particle with initial kinetic energy $E$ and
# wavevector $k_1=\sqrt{2mE}/\hbar$, where $\hbar$ is the Reduced Planck's constant, enters from the left and encounters a
# sudden jump in potential energy of height $V$ at position $x=0$.  By
# solving the Schrodinger equation, one can show that when $E>V$ the
# particle may either (a) pass the step, in which case it has a lower kinetic
# energy of $E-V$ on the other side and a correspondingly smaller wavevector
# of $k_2=\sqrt{2m(E-V)}/\hbar$, or (b) it may be reflected, keeping all of
# its kinetic energy and an unchanged wavevector but moving in the opposite
# direction.  The probabilities $T$ and $R$ for transmission and
# reflection are given by
#
# $
# T = {4k_1k_2\over(k_1+k_2)^2}\,,\qquad
# R = \biggl( {k_1-k_2\over k_1+k_2} \biggr)^2.
# $
#
# Suppose we have a particle with mass equal to the electron mass
# $m=9.11\times10^{-31}\,$kg and energy $10\,$eV encountering a potential
# step of height $9\,$eV.  Write a Python program to compute and print out
# the transmission and reflection probabilities using the formulas above.

# %% [markdown]
# # Solution:

# %% [markdown]
# This program calculates the transmission and reflection probabilities for a particle of mass $m$ and energy $E$.

# %%
import math as m

# %% [markdown]
# User variables:
#
# mass: mass of particle (kg)
#
# energy: energy of particle (eV)
#
# barrier: energy of barrier (eV)

# %%
mass = 9.11e-31
energy = 10.0
barrier = 9.0

# %% [markdown]
# Physical constants:
#
# hbar: reduced planks constant (in eV * s)

# %%
hbar = 6.582e-16

# %% [markdown]
# Calculate the wavevectors k1 and k2 using:
#
# $k_1=\sqrt{2mE}/\hbar$
#
# $k_2=\sqrt{2m(E-V)}/\hbar$
#
#
# Then use these to compute transimission and reflection:
#
# $
# T = {4k_1k_2\over(k_1+k_2)^2}\,,\qquad
# R = \biggl( {k_1-k_2\over k_1+k_2} \biggr)^2.
# $

# %%
k_1 = m.sqrt( 2 * mass * energy) / hbar
k_2 = m.sqrt(2 * mass * (energy - barrier) ) /hbar
T = 4 * k_1 * k_2 / (k_1 + k_2)**2
R = ( ( k_1-k_2 ) / (k_1 + k_2))**2
print("The transmission probability is: ",T)
print("The reflection probability is: ",R)
# Out:
# The transmission probability is:  0.7301261363877617
# The reflection probability is:  0.2698738636122385

# %% [markdown]
# ## Grading for this problem:
#
# 35 points:
#
#
#
# *   10 points: Did the program work and produce the correct output?
# *   10 points: Did you follow our program recipe:
#   * Text cell describing the point of the program
#   * Code cell importing libraries (can be skipped in this assignment since there are none)
#   * Text cell describing the variables that will be edited in this program
#   * Code cell implementing those variables
#   * Text cell describing the variables that are physical constants/won't be changed in this program
#   * Code cell implementing those variables
#   * Alternating text and code cells with text cells describing what will be done in the code cells
# * 5 points: Are all of your variable names descriptive?
# * 5 points: Are units defined and easy to read for all of your variable names?
# * 5 points: Is your output descriptive and include the correct units?
